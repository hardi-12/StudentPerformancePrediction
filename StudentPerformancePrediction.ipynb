# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
dataset=pd.read_csv("career_compute_dataset.csv")

# %%
dataset.head()
# Out:
#    sslc  hsc  cgpa  school_type  no_of_miniprojects  no_of_projects  \
# 0     2    3     2            3                   1               1
# 1     3    1     2            2                   2               1
# 2     3    4     2            2                   1               1
# 3     3    4     2            1                   1               1
# 4     2    3     2            4                   1               1
#
#    coresub_skill  aptitude_skill  problemsolving_skill  programming_skill  \
# 0              1               1                     2                  4
# 1              1               3                     2                  4
# 2              1               2                     3                  3
# 3              1               1                     3                  2
# 4              1               4                     3                  3
#
#    abstractthink_skill  design_skill  ds_coding  technology_used  \
# ...

# %%
dataset.columns
# Out:
# Index(['sslc', 'hsc', 'cgpa', 'school_type', 'no_of_miniprojects',
#        'no_of_projects', 'coresub_skill', 'aptitude_skill',
#        'problemsolving_skill', 'programming_skill', 'abstractthink_skill',
#        'design_skill', 'ds_coding', 'technology_used', 'sympos_attend',
#        'sympos_won', 'extracurricular', 'learning_style',
#        'college_performence ', 'ROLE'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# sslc                     int64
# hsc                      int64
# cgpa                     int64
# school_type              int64
# no_of_miniprojects       int64
# no_of_projects           int64
# coresub_skill            int64
# aptitude_skill           int64
# problemsolving_skill     int64
# programming_skill        int64
# abstractthink_skill      int64
# design_skill             int64
# ds_coding                int64
# technology_used          int64
# sympos_attend            int64
# sympos_won               int64
# extracurricular          int64
# learning_style           int64
# college_performence      int64
# ROLE                    object
# dtype: object

# %%
import missingno as msno

# %%
msno.matrix(dataset)

# %%
dataset.describe()
# Out:
#              sslc         hsc        cgpa  school_type  no_of_miniprojects  \
# count  580.000000  580.000000  580.000000   580.000000          580.000000
# mean     2.927586    3.122414    2.182759     1.948276            1.563793
# std      0.944906    0.905089    0.823476     0.780204            0.784830
# min      1.000000    1.000000    1.000000     1.000000            1.000000
# 25%      2.000000    3.000000    2.000000     1.000000            1.000000
# 50%      3.000000    3.000000    2.000000     2.000000            1.000000
# 75%      4.000000    4.000000    3.000000     2.000000            2.000000
# max      4.000000    4.000000    4.000000     4.000000            4.000000
#
#        no_of_projects  coresub_skill  aptitude_skill  problemsolving_skill  \
# count      580.000000     580.000000      580.000000            580.000000
# mean         1.189655       1.543103        2.037931              2.794828
# ...

# %%
dataset['ROLE'].value_counts()
# Out:
# Software Developer    179
# Technical Support     141
# Web Developer          79
# Software Tester        58
# Business Analyst       53
# Data Analyst           30
# UI/UX Designer         24
# Technical Writer       16
# Name: ROLE, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
fig, ax=plt.subplots(figsize=(20,20))
sns.heatmap(dataset.corr(),annot=True,ax=ax)

# %%
# Plotting Histogram for all
dataset.hist(figsize=(12,12))
plt.show()

# %%
fig, ax=plt.subplots(figsize=(18,15))
sns.barplot(dataset['ROLE'],dataset['extracurricular'],ax=ax)

# %%
fig, ax=plt.subplots(figsize=(18,15))
sns.barplot(dataset['ROLE'],dataset['technology_used'],ax=ax)

# %%
fig, ax=plt.subplots(figsize=(18,15))
sns.barplot(dataset['ROLE'],dataset['no_of_projects'],ax=ax)

# %%
data=dataset.iloc[:,:-1].values
label=dataset.iloc[:,-1].values
data
# Out:
# array([[2, 3, 2, ..., 2, 2, 4],
#        [3, 1, 2, ..., 3, 2, 3],
#        [3, 4, 2, ..., 1, 4, 3],
#        ...,
#        [4, 3, 2, ..., 1, 2, 3],
#        [3, 4, 2, ..., 1, 2, 4],
#        [2, 4, 2, ..., 4, 2, 3]], dtype=int64)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
labelencoder = LabelEncoder()

# %%
label = labelencoder.fit_transform(label)
label
# Out:
# array([4, 2, 6, 4, 1, 5, 7, 4, 5, 3, 2, 4, 7, 2, 2, 7, 5, 2, 4, 5, 4, 0,
#        7, 2, 5, 6, 2, 7, 0, 7, 4, 2, 5, 0, 6, 2, 3, 2, 1, 4, 2, 3, 0, 7,
#        4, 3, 4, 1, 2, 3, 4, 0, 2, 2, 1, 4, 7, 1, 6, 2, 6, 7, 0, 0, 7, 2,
#        3, 6, 2, 0, 4, 2, 2, 4, 4, 4, 4, 3, 1, 4, 3, 2, 3, 7, 2, 2, 2, 7,
#        4, 2, 7, 4, 2, 7, 2, 2, 7, 2, 4, 2, 7, 6, 0, 7, 2, 0, 2, 2, 6, 4,
#        4, 3, 4, 7, 4, 1, 4, 2, 4, 0, 4, 4, 6, 7, 2, 2, 2, 4, 2, 4, 4, 6,
#        2, 2, 1, 2, 0, 2, 3, 3, 2, 3, 4, 2, 2, 2, 3, 7, 0, 3, 2, 7, 0, 2,
#        2, 2, 1, 1, 4, 4, 4, 4, 4, 4, 2, 4, 4, 2, 2, 3, 4, 7, 1, 0, 4, 4,
#        4, 7, 0, 6, 3, 6, 2, 3, 2, 0, 0, 2, 0, 7, 1, 1, 2, 2, 3, 4, 3, 4,
#        2, 1, 0, 4, 3, 2, 0, 2, 2, 3, 7, 2, 4, 0, 2, 4, 4, 4, 4, 2, 4, 7,
#        2, 3, 2, 7, 3, 0, 4, 2, 4, 2, 7, 7, 2, 4, 2, 4, 2, 0, 2, 2, 2, 2,
#        2, 7, 7, 2, 7, 7, 2, 2, 4, 2, 4, 4, 7, 5, 7, 3, 4, 2, 2, 7, 4, 7,
#        3, 3, 2, 5, 2, 4, 4, 4, 0, 2, 2, 4, 3, 2, 7, 2, 0, 4, 7, 4, 4, 4,
# ...

# %%
y=pd.DataFrame(label,columns=["ROLE"])
X1 = pd.DataFrame(data,columns=['sslc','hsc','cgpa','school_type','no_of_miniprojects','no_of_projects','coresub_skill','aptitude_skill','problemsolving_skill','programming_skill','abstractthink_skill','design_skill','ds_coding','technology_used','sympos_attend','sympos_won','extracurricular','learning_style','college_performence'])

# %%
X_train,X_test,y_train,y_test=train_test_split(X1,y,test_size=0.4,random_state=10)

# %%
X_train.shape
# Out:
# (348, 19)

# %%
X_train=pd.to_numeric(X_train.values.flatten())

# %%
X_train=X_train.reshape((348, 19))

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
y = dataset['ROLE'].values
X = dataset.drop('ROLE', axis=1).values
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X,y)
y_pred = knn.predict(X)
x_new = ['2','3','2','3','1','1','1','1','2','4','2','2','1','1','3','1','2','2','4']
new_pred = knn.predict([x_new])
print("Prediction : {}".format(new_pred))
# Out:
# Prediction : ['Technical Support']
# C:\Users\HARDI\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
confusion_matrix(y,y_pred)
# Out:
# array([[ 45,   0,   4,   3,   1,   0,   0,   0],
#        [  0,  18,   2,   4,   6,   0,   0,   0],
#        [ 10,   4, 147,   4,   8,   0,   0,   6],
#        [  5,   2,   9,  34,   8,   0,   0,   0],
#        [  7,  10,  21,  15,  86,   0,   2,   0],
#        [  2,   0,  10,   0,   2,   0,   0,   2],
#        [  4,   0,   4,   4,   6,   0,   6,   0],
#        [  6,   4,  22,   0,   6,   0,   0,  41]], dtype=int64)

# %%
accuracy_score(y,y_pred)
# Out:
# 0.65
